# %%
import  os
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 20

# %% [markdown]
# # Main Result

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/GP2D_GP+EI'), delimiter=',')
BO_EI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/GP2D_GP+EI(perfect hyperparameter)'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/GP2D_logGP(NoBoundary)+logEI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/GP2D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/GP2D_logGP+logTEI'), delimiter=',')

N = 20

total_record = (np.array(BO_EI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_EI2))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI (perfect hyperparameter)',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


total_record =  (np.array(BO_logEI_noBoundary))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = (np.array(BO_logEI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logTEI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('GP 2D')
# Out:
# Text(0.5, 1.0, 'GP 2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/logGP2D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/logGP2D_logGP(NoBoundary)+logEI2'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/logGP2D_logGP+logEI'), delimiter=',')

N = 20

total_record = (np.array(BO_EI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record =  (np.array(BO_logEI_noBoundary))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = (np.array(BO_logEI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logEI))
total_record[total_record<0]=10**(-6)
total_record = np.log10(total_record)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('log-GP 2D')
# Out:
# Text(0.5, 1.0, 'log-GP 2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots/branin4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES_0.2'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM_0.2'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI_0.2'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI_0.2'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D (0.2)')
# Out:
# Text(0.5, 1.0, 'Branin2D (0.2)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES_1'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM_1'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI_1'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI_1'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D (1)')
# Out:
# Text(0.5, 1.0, 'Branin2D (1)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES_5'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM_5'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI_5'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI_5'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D (5)')
# Out:
# Text(0.5, 1.0, 'Branin2D (5)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES_10'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM_10'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI_10'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI_10'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D (10)')
# Out:
# Text(0.5, 1.0, 'Branin2D (10)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+MES_20'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_transformedGP+ERM_20'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+TEI_20'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI_20'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D (20)')
# Out:
# Text(0.5, 1.0, 'Branin2D (20)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')

plt.savefig('exp_plots/beale4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+MES_100'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_transformedGP+ERM_100'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+TEI_100'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI_100'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D (100)')
# Out:
# Text(0.5, 1.0, 'Beale2D (100)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+MES_200'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_transformedGP+ERM_200'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+TEI_200'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI_200'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D (200)')
# Out:
# Text(0.5, 1.0, 'Beale2D (200)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+MES_1000'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_transformedGP+ERM_1000'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+TEI_1000'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI_1000'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D (1000)')
# Out:
# Text(0.5, 1.0, 'Beale2D (1000)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+MES_10000'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_transformedGP+ERM_10000'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+TEI_10000'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI_10000'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D (10000)')
# Out:
# Text(0.5, 1.0, 'Beale2D (10000)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP+logTEI'), delimiter=',')

fstar = -3.86278
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')

plt.savefig('exp_plots/hartmann4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+MES_0.2'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_transformedGP+ERM_0.2'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+TEI_0.2'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP+logTEI_0.2'), delimiter=',')

fstar = -3.86278
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D (0.2)')
# Out:
# Text(0.5, 1.0, 'Hartmann3D (0.2)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')

plt.savefig('exp_plots/powell4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')

plt.savefig('exp_plots/rosen4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')

plt.savefig('exp_plots/ackley4.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Skin_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Skin_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Skin_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Skin_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Skin_logGP+logTEI'), delimiter=',')


N = 20

total_record = (np.array(BO_EI))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_TEI))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('accuracy')

plt.legend()
plt.title('Skin 6D')

plt.savefig('exp_plots/Skin.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Bank_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Bank_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Bank_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Bank_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Bank_logGP+logTEI(general bounday)'), delimiter=',')


N = 20

total_record = (np.array(BO_EI))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('accuracy')

plt.legend()
plt.title('BankNote 6D')

plt.savefig('exp_plots/Bank.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Breast_GP_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Breast_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Breast_transformedGP+ERM'), delimiter=',')
# BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Breast_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Breast_logGP+logTEI(general bounday)'), delimiter=',')


N = 20

BO_EI = ((np.array(BO_EI)) - np.array(BO_EI)[:,0].reshape(20,1))
total_record = (np.array(BO_EI))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


BO_MES = ((np.array(BO_MES)) - np.array(BO_MES)[:,0].reshape(20,1))
total_record = (np.array(BO_MES))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# BO_TEI = ((np.array(BO_TEI)) - np.array(BO_TEI)[:,0].reshape(20,1))
# total_record = (np.array(BO_TEI))
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

BO_ERM = ((np.array(BO_ERM)) - np.array(BO_ERM)[:,0].reshape(20,1))
total_record = (np.array(BO_ERM))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


Warped_BO_TEI2 = ((np.array(Warped_BO_TEI2)) - np.array(Warped_BO_TEI2)[:,0].reshape(20,1))
total_record = (np.array(Warped_BO_TEI2))
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('accuracy')

plt.legend()
plt.title('Breast 6D')
# Out:
# Text(0.5, 1.0, 'Breast 6D')

# %% [markdown]
# # GP vs Log-GP

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.397887

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots/branin1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')

plt.savefig('exp_plots/beale1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = -3.86278

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record =  np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')

plt.savefig('exp_plots/hartmann1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record =  np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')

plt.savefig('exp_plots/powell1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record =  np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')

plt.savefig('exp_plots/rosen1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_GP+EI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record =  (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')

plt.savefig('exp_plots/ackley1.png')

# %% [markdown]
# # Knowing boundary vs Not knowing boundary

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.397887

total_record = (np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots/branin2.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.

total_record = (np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')

plt.savefig('exp_plots/beale2.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = -3.86278

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')

plt.savefig('exp_plots/hartmann2.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')


plt.savefig('exp_plots/powell2.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')

plt.savefig('exp_plots/rosen2.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP(NoBoundary)+logEI'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')

plt.savefig('exp_plots/ackley2.png')

# %% [markdown]
# # logEI vs LogTEI

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logGP+logTEI'), delimiter=',')

fstar = 0.397887

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots/branin3.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Beale2D')

plt.savefig('exp_plots/beale3.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logGP+logTEI'), delimiter=',')

fstar = -3.86278

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')

plt.savefig('exp_plots/hartmann3.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')

plt.savefig('exp_plots/powell3.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = np.log10(np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')

plt.savefig('exp_plots/rosen3.png')

# %%
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP+logEI'), delimiter=',')
BO_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = (np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')

total_record = (np.array(BO_logTEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')

plt.savefig('exp_plots/ackley3.png')
