# %%
import  os
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Robot Push 4D')

plt.savefig('exp_plots2/push.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI'), delimiter=',')


fstar = 0.397887
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')



total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')


#plt.savefig('exp_plots2/branin2.png')
# Out:
# Text(0.5, 1.0, 'Branin2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+TEI'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)'), delimiter=',')


fstar = 0.397887
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = (np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')


plt.savefig('exp_plots2/branin2_0.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+MES_5'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_transformedGP+ERM_5'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+TEI_5'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)_5'), delimiter=',')


fstar = 0.397887
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = (np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')


plt.savefig('exp_plots2/branin2_5.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+MES_10'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_transformedGP+ERM_10'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+TEI_10'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)_10'), delimiter=',')


fstar = 0.397887
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = (np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots2/branin2_10.png')

# %%
Warped_BO_TEI1_10 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)_10'), delimiter=',')
Warped_BO_TEI1_5 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)_5'), delimiter=',')
Warped_BO_TEI1_0 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI(general boundary)'), delimiter=',')

total_record = np.log10(np.array(Warped_BO_TEI1_0)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary)',color='blue')
#plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(Warped_BO_TEI1_5)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary) 5',color='red')
#plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='red')

total_record = np.log10(np.array(Warped_BO_TEI1_10)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary) 10',color='black')
#plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.legend()

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_logGP+logTEI'), delimiter=',')

fstar = 0.397887

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Branin2D')

plt.savefig('exp_plots2/branin1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+EI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = (-np.array(BO_KG)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+KG',color='pink')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='pink')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')

#plt.savefig('exp_plots2/beale2.png')
# Out:
# Text(0.5, 1.0, 'Beale2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')


plt.legend()
plt.title('Beale2D')

plt.savefig('exp_plots2/beale1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_logGP+logTEI'), delimiter=',')

fstar = -3.86278
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')


plt.savefig('exp_plots2/hartmann2.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_logGP+logTEI'), delimiter=',')

fstar = -3.86278

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')

plt.savefig('exp_plots2/hartmann1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record =  np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')


plt.savefig('exp_plots2/powell2.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+TEI'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)'), delimiter=',')


fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = np.log10(np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D')
# Out:
# Text(0.5, 1.0, 'Powell4D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+MES_20'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_transformedGP+ERM_20'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+TEI_20'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)_20'), delimiter=',')


fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = np.log10(np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D (-20)')
# Out:
# Text(0.5, 1.0, 'Powell4D (-20)')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+MES_100'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_transformedGP+ERM_100'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+TEI_100'), delimiter=',')
Warped_BO_TEI1 = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)_100'), delimiter=',')


fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')


total_record = np.log10(np.array(Warped_BO_TEI1)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI* (general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')




plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D (-100)')
# Out:
# Text(0.5, 1.0, 'Powell4D (-100)')

# %%
a = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI'), delimiter=',')
b=np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)'), delimiter=',')
c=np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)_20'), delimiter=',')
d =np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP(NoBoundary)+logEI'), delimiter=',')
e =np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI(general boundary)_100'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(a)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logTEI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(b)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='0')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)


total_record = np.log10(np.array(c)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='-20')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(e)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='-100')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(d)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='no boundary')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Powell4D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Powell4D')


#plt.savefig('exp_plots2/powell1.png')
# Out:
# Text(0.5, 1.0, 'Powell4D')

# %%
total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
mean[-1]
# Out:
# -0.15339920960319367

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')


#plt.savefig('exp_plots2/rosenbrock2.png')
# Out:
# Text(0.5, 1.0, 'Rosenbrock5D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*(general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')


plt.savefig('exp_plots2/rosenbrock2_0.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+MES_200'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_transformedGP+ERM_200'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+TEI_200'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)_200'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*(general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')

plt.savefig('exp_plots2/rosenbrock2_200.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+MES_1000'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_transformedGP+ERM_1000'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+TEI_1000'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)_1000'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = np.log10(np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*(general boundary)',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')


plt.savefig('exp_plots2/rosenbrock2_1000.png')

# %%
a = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI'), delimiter=',')
b=np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)'), delimiter=',')
c=np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)_200'), delimiter=',')
d =np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP(NoBoundary)+logEI'), delimiter=',')
e =np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI(general boundary)_1000'), delimiter=',')

fstar = 0.
N = 100

total_record = np.log10(np.array(a)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logTEI')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(b)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='0')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)


total_record = np.log10(np.array(c)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='-200')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(e)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='-1000')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)

total_record = np.log10(np.array(d)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='no boundary')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25)


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock5D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = np.log10(np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')


plt.savefig('exp_plots2/rosenbrock1.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_GP+TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')



total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Ackley7D')


plt.savefig('exp_plots2/ackley2.png')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_GP+EI'), delimiter=',')
BO_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_logGP+logEI'), delimiter=',')
BO_logEI_noBoundary = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_logGP(NoBoundary)+logEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_logGP+logTEI'), delimiter=',')

fstar = 0.

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = (np.array(BO_logEI_noBoundary)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP+logEI',color='maroon')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='maroon')

total_record = (np.array(BO_logEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,linestyle='dashed',label='logGP*+logEI',color='navy')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='navy')


total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Ackley7D')


#plt.savefig('exp_plots2/ackley1.png')
# Out:
# Text(0.5, 1.0, 'Ackley7D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley10D_GP+EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Ackley10D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Ackley10D_transformedGP+ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley10D_GP+TEI'), delimiter=',')
# Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'Ackley7D_logGP+logTEI'), delimiter=',')

fstar = 0.
N = 100

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_TEI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='orange')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='orange')

# total_record = (np.array(Warped_BO_TEI2)-fstar)
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='logGP*+logTEI*',color='black')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Ackley10D')
# Out:
# Text(0.5, 1.0, 'Ackley10D')
